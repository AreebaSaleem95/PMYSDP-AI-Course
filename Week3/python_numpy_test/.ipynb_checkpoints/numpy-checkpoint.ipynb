# %% [markdown]
# # Q: User se space-separated numbers lo aur NumPy array bana kar print karo.
# Example input:
# 1 2 3 4 5

# %% [markdown]
# # Q: User se numbers lo aur array ka:
#
# - max
#
# - min
#
# - sum
#
# print karo.

# %% [markdown]
# # Q: User se numbers lo aur unka square print karo.

# %% [markdown]
# # Q: User se numbers lo aur:
#
# - even numbers filter karo
#
# - odd numbers filter karo

# %% [markdown]
# # Q: User se numbers lo aur array ko ascending order me sort karo.

# %% [markdown]
# # Q: User se numbers lo aur array ka dtype change karke float bana do.

# %% [markdown]
# # Q: User se numbers lo aur array ka dtype change karke float bana do.
# Example:
# rows = 2
# cols = 3

# %% [markdown]
# # Q: User se matrix lo aur transpose print karo.

# %% [markdown]
# # Q: User se matrix lo aur:
#
# - maximum element
#
# - minimum element
#
# print karo.

# %% [markdown]
# # Q: User se matrix lo aur har element me 5 add karo (broadcasting use karo).

# %% [markdown]
# # Q: User se 2 matrices lo aur unka dot product karo.

# %% [markdown]
# # Q: User se numbers lo aur array ko reshape karke 2D bana do.
