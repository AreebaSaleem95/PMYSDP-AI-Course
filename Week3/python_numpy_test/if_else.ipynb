# %% [markdown]
# # Q: Take a number from user and check whether it is even or odd.

# %% [markdown]
# # Q: Take a number and check whether it is positive, negative, or zero.

# %% [markdown]
# # Q: Take age as input and check:
#
# - If age ≥ 18 → “Eligible to vote”
#
# - Otherwise → “Not eligible"

# %% [markdown]
# # Q: Take marks as input and print grade:
#
# - 90+ → A
#
# - 75–89 → B
#
# - 50–74 → C
#
# - Below 50 → Fail

# %% [markdown]
# # Q: Take 3 numbers and print the largest using if-else (do NOT use max()).
